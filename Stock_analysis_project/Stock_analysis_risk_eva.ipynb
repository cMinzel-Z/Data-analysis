# %%
# basic info
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# stock data obtain
import pandas_datareader as pdr

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# time
from datetime import datetime

# %%
start = datetime(2015,1,1)
company = ['AAPL','GOOG','MSFT','AMZN','FB']
top_tech_df = pdr.get_data_yahoo(company, start=start)['Adj Close']

# %%
top_tech_df.to_csv('top5.csv')

# %%
top_tech_df.head()
# Out:
# Symbols           AAPL        GOOG       MSFT        AMZN         FB
# Date
# 2015-01-02  100.216454  523.373108  41.864841  308.519989  78.449997
# 2015-01-05   97.393181  512.463013  41.479866  302.190002  77.190002
# 2015-01-06   97.402374  500.585632  40.871037  295.290009  76.150002
# 2015-01-07   98.768150  499.727997  41.390320  298.420013  76.150002
# 2015-01-08  102.563072  501.303680  42.607944  300.459991  78.180000

# %%
top_tech_dr = top_tech_df.pct_change()

# %%
top_tech_dr.head()
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN        FB
# Date
# 2015-01-02       NaN       NaN       NaN       NaN       NaN
# 2015-01-05 -0.028172 -0.020846 -0.009196 -0.020517 -0.016061
# 2015-01-06  0.000094 -0.023177 -0.014678 -0.022833 -0.013473
# 2015-01-07  0.014022 -0.001713  0.012705  0.010600  0.000000
# 2015-01-08  0.038423  0.003153  0.029418  0.006836  0.026658

# %%
top_tech_df.plot()

# %%
top_tech_df[['AAPL','FB','MSFT']].plot()

# %%
sns.jointplot('AMZN','GOOG', top_tech_dr, kind='scatter')

# %%
sns.jointplot('MSFT','FB', top_tech_dr, kind='scatter')

# %%
sns.pairplot(top_tech_dr.dropna())

# %% [markdown]
# # 分位数

# %%
top_tech_dr['AAPL'].quantile(0.52)
# Out:
# 0.001275789639597936

# %%
top_tech_dr['MSFT'].quantile(0.05)
# Out:
# -0.02281456550700009

# %%
vips = pdr.get_data_yahoo('VIPS', start=start)['Adj Close']
vips.plot()

# %%
vips.pct_change().quantile(0.2)
# Out:
# -0.022842677990056348

# %%
vips.plot(rwidth=0.9, kind='hist')
