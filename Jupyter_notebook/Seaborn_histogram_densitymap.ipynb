# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

# %%
import seaborn as sns

# %% [markdown]
# # 回顾Matplotlib实现直方图和密度图

# %%
s1 = Series(np.random.randn(1000))

# %%
plt.hist(s1, rwidth=0.9)
# Out:
# (array([  3.,  19.,  55., 149., 243., 245., 168.,  81.,  31.,   6.]),
#  array([-3.21909271, -2.59940194, -1.97971118, -1.36002042, -0.74032965,
#         -0.12063889,  0.49905188,  1.11874264,  1.7384334 ,  2.35812417,
#          2.97781493]),
#  <a list of 10 Patch objects>)

# %%
s1.plot(kind='kde')

# %% [markdown]
# # 通过Seaborn实现

# %%
sns.distplot(s1, hist=True, kde=False)

# %%
sns.distplot(s1, hist=False, kde=True)

# %%
sns.distplot(s1,bins=20, hist=True, kde=False, rug=True)

# %%
sns.kdeplot(s1, shade=True, color='r')

# %%
plt.plot(s1)

# %%
sns.set()

# %%
plt.hist(s1)
# Out:
# (array([  3.,  19.,  55., 149., 243., 245., 168.,  81.,  31.,   6.]),
#  array([-3.21909271, -2.59940194, -1.97971118, -1.36002042, -0.74032965,
#         -0.12063889,  0.49905188,  1.11874264,  1.7384334 ,  2.35812417,
#          2.97781493]),
#  <a list of 10 Patch objects>)

# %%
sns.rugplot(s1)
