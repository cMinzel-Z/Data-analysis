# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# x坐标是index, y坐标是b的值, a充当index
a = [1,2,3]
b = [4,5,6]
plt.plot(a, b, '*')

# %%
# %timeit np.arange(10)
# Out:
# 570 ns ± 35.5 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
plt.plot(a, b, '--')

# %%
plt.plot(a, b, 'b--')

# %%
plt.plot(a, b, 'r--')

# %%
c = [10,8,6]
d = [1,8,3]
plt.plot(a,b,'r--', c,d, 'b*')
# Out:
# [<matplotlib.lines.Line2D at 0x29c808d8888>,
#  <matplotlib.lines.Line2D at 0x29c808d8a08>]

# %%
t = np.arange(0.0,2.0,0.1)

# %%
t.size
# Out:
# 20

# %%
s = np.sin(t*np.pi)

# %%
s
# Out:
# array([ 0.00000000e+00,  3.09016994e-01,  5.87785252e-01,  8.09016994e-01,
#         9.51056516e-01,  1.00000000e+00,  9.51056516e-01,  8.09016994e-01,
#         5.87785252e-01,  3.09016994e-01,  1.22464680e-16, -3.09016994e-01,
#        -5.87785252e-01, -8.09016994e-01, -9.51056516e-01, -1.00000000e+00,
#        -9.51056516e-01, -8.09016994e-01, -5.87785252e-01, -3.09016994e-01])

# %%
s.size
# Out:
# 20

# %%
plt.plot(t,s,'r--',label='aaaa')
plt.plot(t*2, s, '--',label='bbbb')
plt.xlabel('This is x')
plt.ylabel('This is y')
plt.title('This is a demo')
plt.legend()
